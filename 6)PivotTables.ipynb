# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    117     93   John  January      Q1
# 1  2023-01-02       B   West    294     25   Mary  January      Q1
# 2  2023-01-03       C  North    442     60    Bob  January      Q1
# 3  2023-01-04       D  South    509     86  Alice  January      Q1
# 4  2023-01-05       A   East    943     21   John  January      Q1
# 5  2023-01-06       B   West    759     25   Mary  January      Q1
# 6  2023-01-07       C  North    495     52    Bob  January      Q1
# 7  2023-01-08       D  South    875     51  Alice  January      Q1
# 8  2023-01-09       A   East    929     72   John  January      Q1
# 9  2023-01-10       B   West    881     10   Mary  January      Q1
# 10 2023-01-11       C  North    183     53    Bob  January      Q1
# 11 2023-01-12       D  South    770     71  Alice  January      Q1
# 12 2023-01-13       A   East    540     39   John  January      Q1
# 13 2023-01-14       B   West    609     56   Mary  January      Q1
# 14 2023-01-15       C  North    501     41    Bob  January      Q1
# 15 2023-01-16       D  South    174     37  Alice  January      Q1
# 16 2023-01-17       A   East    718     92   John  January      Q1
# 17 2023-01-18       B   West    193     24   Mary  January      Q1
# 18 2023-01-19       C  North    605     63    Bob  January      Q1
# 19 2023-01-20       D  South    414     51  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     649.4    NaN    NaN    NaN
# North      NaN    NaN  445.2    NaN
# South      NaN    NaN    NaN  548.4
# West       NaN  547.2    NaN    NaN

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='std')
# Out:
# Product           A           B           C           D
# Region
# East     340.771624         NaN         NaN         NaN
# North           NaN         NaN  158.025947         NaN
# South           NaN         NaN         NaN  280.875951
# West            NaN  295.663998         NaN         NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')  # Aggerigation functions are use only for numerical values 
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     649.4    NaN    NaN    NaN  63.4   NaN   NaN   NaN
# North      NaN    NaN  445.2    NaN   NaN   NaN  53.8   NaN
# South      NaN    NaN    NaN  548.4   NaN   NaN   NaN  59.2
# West       NaN  547.2    NaN    NaN   NaN  28.0   NaN   NaN

# %% [markdown]
# Creos Tab

# %%
# Cross tab is use for countable functions

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
