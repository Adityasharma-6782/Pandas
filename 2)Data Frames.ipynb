# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Creating data frames**

# %%
data = {
    'Name': ['john','anna', 'peter', 'linda'],
    'Age': [28,34,29,42],
    'City': ['jaipur', 'Delhi', 'Kota', 'Sikar'],
    'Salary': [65000,32000,76000,52000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age    City  Salary
# 0   john   28  jaipur   65000
# 1   anna   34   Delhi   32000
# 2  peter   29    Kota   76000
# 3  linda   42   Sikar   52000

# %%
data_list = [
    ['jhon', 20, 'jaipur', 65000],
    ['anna', 30, 'Delhi', 34000],
    ['peter', 29, 'Kota', 69000],
    ['Linda', 69, 'sikar', 26000]
]
df1 = pd.DataFrame(data_list)

# %%
df1
# Out:
#        0   1       2      3
# 0   jhon  20  jaipur  65000
# 1   anna  30   Delhi  34000
# 2  peter  29    Kota  69000
# 3  Linda  69   sikar  26000

# %%
columns = ['Name', 'Age', 'City', 'Salary']

# %%
# df3 = pd.DataFrame(data_list, columns)
df2 = pd.DataFrame(data_list, columns= columns)
df2
# Out:
#     Name  Age    City  Salary
# 0   jhon   20  jaipur   65000
# 1   anna   30   Delhi   34000
# 2  peter   29    Kota   69000
# 3  Linda   69   sikar   26000

# %% [markdown]
# **selection and indexinf**

# %%
df1[0]  # --> List me index 0,1,2,...
# Out:
# 0     jhon
# 1     anna
# 2    peter
# 3    Linda
# Name: 0, dtype: object

# %%
df2['Name']  # --> Dictionary me indexing by labels hoti hai
# Out:
# 0     jhon
# 1     anna
# 2    peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','City']] # Multiple Column Select at a time
# Out:
#     Name    City
# 0   jhon  jaipur
# 1   anna   Delhi
# 2  peter    Kota
# 3  Linda   sikar

# %% [markdown]
# Create a new column

# %%
# add column work
df2["Work"] = ['A', 'B', 'C', 'D']

# %%
df2
# Out:
#     Name  Age    City  Salary Work
# 0   jhon   20  jaipur   65000    A
# 1   anna   30   Delhi   34000    B
# 2  peter   29    Kota   69000    C
# 3  Linda   69   sikar   26000    D

# %%
df2['Work']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Work, dtype: object

# %% [markdown]
# Remove a column

# %%
df2.drop('Work', axis=1)   # without axis is gives error, pure area ko remove nhi karta hai
# Out:
#     Name  Age    City  Salary
# 0   jhon   20  jaipur   65000
# 1   anna   30   Delhi   34000
# 2  peter   29    Kota   69000
# 3  Linda   69   sikar   26000

# %%
df2
# Out:
#     Name  Age    City  Salary Work
# 0   jhon   20  jaipur   65000    A
# 1   anna   30   Delhi   34000    B
# 2  peter   29    Kota   69000    C
# 3  Linda   69   sikar   26000    D

# %%
df2.drop('Work', axis=1, inplace=True)  # --> it parmanently remove

# %%
df2
# Out:
#     Name  Age    City  Salary
# 0   jhon   20  jaipur   65000
# 1   anna   30   Delhi   34000
# 2  peter   29    Kota   69000
# 3  Linda   69   sikar   26000

# %%
row = ['a','b','c','d']
df3 = pd.DataFrame(data_list, columns = columns, index=row)

# %%
df3
# Out:
#     Name  Age    City  Salary
# a   jhon   20  jaipur   65000
# b   anna   30   Delhi   34000
# c  peter   29    Kota   69000
# d  Linda   69   sikar   26000

# %%
df3.drop('a')  # --> pure area ko remove nhi karta hai
# Out:
#     Name  Age   City  Salary
# b   anna   30  Delhi   34000
# c  peter   29   Kota   69000
# d  Linda   69  sikar   26000

# %%
df3
# Out:
#     Name  Age    City  Salary
# a   jhon   20  jaipur   65000
# b   anna   30   Delhi   34000
# c  peter   29    Kota   69000
# d  Linda   69   sikar   26000

# %%
# remove multiple data at a time
df3.drop(['City', 'Salary'], axis = 1, inplace=True)

# %%
df3
# Out:
#     Name  Age
# a   jhon   20
# b   anna   30
# c  peter   29
# d  Linda   69

# %%
# df3 = df2.copy()
df3 = df2
df3
# Out:
#     Name  Age    City  Salary
# 0   jhon   20  jaipur   65000
# 1   anna   30   Delhi   34000
# 2  peter   29    Kota   69000
# 3  Linda   69   sikar   26000

# %%
# select single row
df3.loc[0] # loc() --> Location
# Out:
# Name        jhon
# Age           20
# City      jaipur
# Salary     65000
# Name: 0, dtype: object

# %%
# Select Multiple rows
df3.loc[[0,2]]
# Out:
#     Name  Age    City  Salary
# 0   jhon   20  jaipur   65000
# 2  peter   29    Kota   69000

# %% [markdown]
# Selecting Subset of Rows and Columns

# %%
df3.loc[[0,1],['Name','Age']]
# Out:
#    Name  Age
# 0  jhon   20
# 1  anna   30

# %%
df3.loc[[0,1]][['Name','Salary']]
# Out:
#    Name  Salary
# 0  jhon   65000
# 1  anna   34000

# %% [markdown]
# Conditional Selection

# %%
df2
# Out:
#     Name  Age    City  Salary Work
# 0   jhon   20  jaipur   65000    A
# 1   anna   30   Delhi   34000    B
# 2  peter   29    Kota   69000    C
# 3  Linda   69   sikar   26000    D

# %%
df2[df2['Age']>=30 ]
# Out:
#     Name  Age   City  Salary
# 1   anna   30  Delhi   34000
# 3  Linda   69  sikar   26000

# %%
df2[(df2['Age']>=30) & (df2['Salary']>30000)]
# Out:
#    Name  Age   City  Salary Work
# 1  anna   30  Delhi   34000    B
