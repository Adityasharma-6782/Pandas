# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas Series  --> vertical

# %%
labels = ['a','b','c']
list = [10,20,30]
arr = np.array([10,20,30])
d = {'name':'Aditya',' age':20, 'Address':'Jaipur'}

# %%
pd.Series(list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# pd.Series(list, index=labels,name='adi',copy=True)  # pd.Series(list, ladels)
pd.Series(list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# name       Aditya
#  age           20
# Address    Jaipur
# dtype: object

# %%
DATA FRAMES
